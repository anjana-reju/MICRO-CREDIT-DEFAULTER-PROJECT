# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %% [markdown]
# Importing the libraries for data preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Loading the csv file and assigning the name d1 for the file

# %%
d1=pd.read_csv("micro_credit.csv",parse_dates=["pdate"])
d1.head()
# Out:
#    index  label       msisdn    aon  daily_decr30  daily_decr90  rental30  \
# 0      1      0  21408I70789  272.0   3055.050000   3065.150000    220.13
# 1      2      1  76462I70374  712.0  12122.000000  12124.750000   3691.26
# 2      3      1  17943I70372  535.0   1398.000000   1398.000000    900.13
# 3      4      1  55773I70781  241.0     21.228000     21.228000    159.42
# 4      5      1  03813I82730  947.0    150.619333    150.619333   1098.90
#
#    rental90  last_rech_date_ma  last_rech_date_da  ...  maxamnt_loans30  \
# 0    260.13                2.0                0.0  ...              6.0
# 1   3691.26               20.0                0.0  ...             12.0
# 2    900.13                3.0                0.0  ...              6.0
# 3    159.42               41.0                0.0  ...              6.0
# 4   1098.90                4.0                0.0  ...              6.0
#
#    medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# ...

# %%
d1.shape
# Out:
# (209593, 37)

# %% [markdown]
# there are 209593 rows and 37 columns in this dataset

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 37 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   index                 209593 non-null  int64
#  1   label                 209593 non-null  int64
#  2   msisdn                209593 non-null  object
#  3   aon                   209593 non-null  float64
#  4   daily_decr30          209593 non-null  float64
#  5   daily_decr90          209593 non-null  float64
#  6   rental30              209593 non-null  float64
#  7   rental90              209593 non-null  float64
#  8   last_rech_date_ma     209593 non-null  float64
#  9   last_rech_date_da     209593 non-null  float64
#  10  last_rech_amt_ma      209593 non-null  int64
#  11  cnt_ma_rech30         209593 non-null  int64
#  12  fr_ma_rech30          209593 non-null  float64
#  13  sumamnt_ma_rech30     209593 non-null  float64
# ...

# %% [raw]
# #OBSERVATION
# 1)This shows there are no null values in this dataset
# 2)Data entry ranges from 0 to 209593
# 3)msisdnand, pcircle are object datatypes and other attributes are float and integer datatypes
# 4)pdate is in datetime datatype

# %%
#there are two index columns,so we can remove one
d1.drop('index',axis=1,inplace=True)

# %%
d1.columns
# Out:
# Index(['label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90', 'rental30',
#        'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %% [markdown]
# Detail description of each column

# %% [raw]
# label - 1:loan paid within 5 days(non defaulter)
#         0:not paid within 5 days(defaulter)
# msisdn -mobile no: of user
# aon -age on cellular network
# daily_decr30 -average amount spent daily for 30 days
# daily_decr90 -average amount spent daily for 90 days
# rental30 -average main account balance for 30 days
# rental90 -average main account balance for 90 days
# last_rech_date_ma -no.of days till last recharge of main account
# last_rech_date_da -no.of days till last recharge of data account
# cnt_ma_rech30 - no.of times main account recharged in 30 days
# fr_ma_rech30 - frequency of main account recharged in 30 days
# sumamnt_ma_rech30 -total amount of recharge in main account for 30 days
# medianamnt_ma_rech30 -median of amount of recharge in main account for 30 days
# medianmarechprebal30 -median of account balance before recharge for 30 days
# cnt_ma_rech90 -no.of times main account recharged in 90 days
# fr_ma_rech90 -frequency of main account recharged in 90 days
# sumamnt_ma_rech90 -total amount of recharge in main account in 90 days
# medianamnt_ma_rech90 -median of amount of recharge in 90 days
# medianmarechprebal90 -median of main account balance just before recharge
# cnt_da_rech30 -no.of times data account recharged in 30 days
# fr_da_rech30 - frequency of data account recharged in 30 days
# cnt_da_rech90 -no.of times data account recharged in 90 days
# fr_da_rech90 -frequency of data account recharged in 90 days
# cnt_loans30 -no.of loans taken in last 30 days
# amnt_loans30 -total amount of loan taken in 30 days
# maxamnt_loans30 -maximum amount of loan taken in 30 days
# medianamnt_loans30 -median amount of loan taken in 30 days
# cnt_loans90 -no.of loans taken in last 90 days
# amnt_loans90 -total amount of loan taken in 90 days
# maxamnt_loans90 -maximum amount of loan taken in 90 days
# medianamnt_loans90 -median amount of loan taken in 90 days
# payback30 -average payback time in days over last 30 days
# payback90 -average payback time in days over last 90 days
# pcircle -telecom circle
# pdate -date

# %%
d1.head()
# Out:
#    label       msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  21408I70789  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  76462I70374  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  17943I70372  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  55773I70781  241.0     21.228000     21.228000    159.42    159.42
# 4      1  03813I82730  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# 0                2.0                0.0              1539  ...
# 1               20.0                0.0              5787  ...
# 2                3.0                0.0              1539  ...
# 3               41.0                0.0               947  ...
# 4                4.0                0.0              2309  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# ...

# %%
#converting datetime datatype of pdate into integer datatype by creating separate columns for date,month and year .
d1["year"]=d1['pdate'].dt.year
d1["month"]=d1['pdate'].dt.month
d1["day"]=d1['pdate'].dt.day
d1.drop('pdate',axis=1,inplace=True)

# %% [markdown]
# Checking datatypes of each column

# %%
d1.dtypes
# Out:
# label                     int64
# msisdn                   object
# aon                     float64
# daily_decr30            float64
# daily_decr90            float64
# rental30                float64
# rental90                float64
# last_rech_date_ma       float64
# last_rech_date_da       float64
# last_rech_amt_ma          int64
# cnt_ma_rech30             int64
# fr_ma_rech30            float64
# sumamnt_ma_rech30       float64
# medianamnt_ma_rech30    float64
# medianmarechprebal30    float64
# cnt_ma_rech90             int64
# fr_ma_rech90              int64
# sumamnt_ma_rech90         int64
# medianamnt_ma_rech90    float64
# medianmarechprebal90    float64
# cnt_da_rech30           float64
# fr_da_rech30            float64
# cnt_da_rech90             int64
# fr_da_rech90              int64
# cnt_loans30               int64
# amnt_loans30              int64
# maxamnt_loans30         float64
# medianamnt_loans30      float64
# cnt_loans90             float64
# ...

# %% [markdown]
# Checking the number of unique values in each column

# %%
d1.nunique()
# Out:
# label                        2
# msisdn                  186243
# aon                       4507
# daily_decr30            146328
# daily_decr90            155483
# rental30                131338
# rental90                139036
# last_rech_date_ma         1186
# last_rech_date_da         1174
# last_rech_amt_ma            70
# cnt_ma_rech30               71
# fr_ma_rech30              1083
# sumamnt_ma_rech30        15141
# medianamnt_ma_rech30       510
# medianmarechprebal30     23907
# cnt_ma_rech90              110
# fr_ma_rech90                89
# sumamnt_ma_rech90        31771
# medianamnt_ma_rech90       608
# medianmarechprebal90     22694
# cnt_da_rech30             1066
# fr_da_rech30              1072
# cnt_da_rech90               27
# fr_da_rech90                46
# cnt_loans30                 40
# amnt_loans30                48
# maxamnt_loans30           1050
# medianamnt_loans30           6
# cnt_loans90               1110
# amnt_loans90                69
# ...

# %% [raw]
# #This shows the no.of data categories in each columns.
# 1)Label is our target column and it has only 2 categories.that is defaulter and non defaulter
# 2)In the date columns we can see the survey is done in the year 2016,on all the days of month-June,July and August
# 3)All the datas collected comes under the same circle UPW
# 4)All other columns have many categories of datas that we are going to analyse

# %% [markdown]
# Checking the maximum and minimum values in each column

# %%
for column in d1.columns:
    print(f"=======Column: {column}=======")
    print(f"Number of unique values: {d1[column].nunique()}")
    print(f"Max: {d1[column].max()}")
    print(f"Min: {d1[column].min()}")
# Out:
# =======Column: label=======
# Number of unique values: 2
# Max: 1
# Min: 0
# =======Column: msisdn=======
# Number of unique values: 186243
# Max: 99998I95206
# Min: 00004I82738
# =======Column: aon=======
# Number of unique values: 4507
# Max: 999860.7552
# Min: -48.0
# =======Column: daily_decr30=======
# Number of unique values: 146328
# Max: 265926.0
# Min: -93.01266667
# =======Column: daily_decr90=======
# Number of unique values: 155483
# Max: 320630.0
# Min: -93.01266667
# =======Column: rental30=======
# Number of unique values: 131338
# Max: 198926.11
# Min: -23737.14
# =======Column: rental90=======
# Number of unique values: 139036
# Max: 200148.11
# Min: -24720.58
# =======Column: last_rech_date_ma=======
# Number of unique values: 1186
# Max: 998650.3777
# Min: -29.0
# =======Column: last_rech_date_da=======
# Number of unique values: 1174
# Max: 999171.8094
# Min: -29.0
# =======Column: last_rech_amt_ma=======
# Number of unique values: 70
# Max: 55000
# Min: 0
# ...

# %% [markdown]
# The negative values shows there are unrealistic values in our dataset

# %%
#Checking the value counts of each attribute
for attr in d1.columns:
    print("\n",attr)
    print(d1[attr].value_counts())
# Out:
#  label
# 1    183431
# 0     26162
# Name: label, dtype: int64
#
#  msisdn
# 04581I85330    7
# 47819I90840    7
# 22038I88658    6
# 71742I90843    6
# 55809I89238    6
#               ..
# 31705I88680    1
# 54737I85330    1
# 16877I91197    1
# 12605I85328    1
# 20135I89230    1
# Name: msisdn, Length: 186243, dtype: int64
#
#  aon
# 95.0000        392
# 92.0000        362
# 96.0000        357
# 99.0000        356
# 157.0000       349
#               ...
# 832037.7123      1
# 932056.6019      1
# 890451.7726      1
# 670233.0281      1
# 919992.9709      1
# Name: aon, Length: 4507, dtype: int64
#
#  daily_decr30
# 0.000000        4144
# 500.000000       829
# 1000.000000      569
# 700.000000       381
# 600.000000       354
#                 ...
# 2074.366667        1
# 3210.520000        1
# 10279.402670       1
# 94.225000          1
# 3265.066667        1
# Name: daily_decr30, Length: 146328, dtype: int64
#
#  daily_decr90
# 0.00        4063
# 500.00       782
# ...

# %%
print(d1["year"].unique())
# Out:
# [2016]

# %% [markdown]
# since all the data is collected in the year 2016 and there are no other categories,so we can drop this column.All the users use a single cellular network,so we can drop this column also.The mobile no. in this dataset is for the person identification,it can also be dropped.

# %%
d1.drop('year',axis=1,inplace=True)
d1.drop('pcircle',axis=1,inplace=True)
d1.drop('msisdn',axis=1,inplace=True)

# %%
d1.isnull().values.any()
# Out:
# False

# %% [markdown]
# This shows there are no null values in this dataset.

# %%
#presence of null values can be checked in visual method using heatmap
sns.heatmap(d1.isnull())

# %% [markdown]
# since the lines are continous and non interrupted,there are no null values present

# %%
d1.describe()
# Out:
#                label            aon   daily_decr30   daily_decr90  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177    8112.343445    5381.402289    6082.515068
# std         0.330519   75696.082531    9220.623400   10918.812767
# min         0.000000     -48.000000     -93.012667     -93.012667
# 25%         1.000000     246.000000      42.440000      42.692000
# 50%         1.000000     527.000000    1469.175667    1500.000000
# 75%         1.000000     982.000000    7244.000000    7802.790000
# max         1.000000  999860.755200  265926.000000  320630.000000
#
#             rental30       rental90  last_rech_date_ma  last_rech_date_da  \
# count  209593.000000  209593.000000       209593.00000      209593.000000
# mean     2692.581910    3483.406534         3755.84780        3712.202921
# std      4308.586781    5770.461279        53905.89223       53374.833430
# min    -23737.140000  -24720.580000          -29.00000         -29.000000
# ...

# %% [raw]
# OBSERVATION
# 1)Description table gives an idea about total rows,minimum,maximum,mean,median,25%,75% and std deviation of each columns in our dataset.
# 2) There are 209593 rows
# 3)mean is highest for daily_decr90 and lowest for medianamnt_loans90
# 4)minimum value for aon,daily_decr30 ,dailydecr90,rental30,rental90,last_rech_date_ma,last_rech_date_da are showing negative values.So there are outliers in this dataset
# 5)There is a large difference between 75% and maximum for almost all columns,this shows there are presence of outliers in this dataset.
# 6)Outliers must be treated to get a better analysis and a better accuracy

# %%
d1cor=d1.corr()
plt.figure(figsize=(18,22))
sns.heatmap(d1cor,cmap='Blues',annot=True,fmt='.0%')
plt.show()

# %% [raw]
# OBSERVATIONS
# 1)correlation map shows the correlation between each columns.
# 2)Label is having a strong positive correlation with cnt_ma_rech30, cnt_ma_rech90, sumamnt_ma_rech90, cnt_loans30,amnt_loans30 ,amnt_loans90
# 3)label is having a negative correlation with fr_da_rech90

# %% [markdown]
# This correlation heatmap can be expressed in matrix form also.It is displayed in descending order.columns with least correlation with target column are displayed at last.

# %%
corr_matrix=d1.corr()
print(corr_matrix["label"].sort_values(ascending=False))
# Out:
# label                   1.000000
# cnt_ma_rech30           0.237331
# cnt_ma_rech90           0.236392
# sumamnt_ma_rech90       0.205793
# sumamnt_ma_rech30       0.202828
# amnt_loans90            0.199788
# amnt_loans30            0.197272
# cnt_loans30             0.196283
# daily_decr30            0.168298
# daily_decr90            0.166150
# month                   0.154949
# medianamnt_ma_rech30    0.141490
# last_rech_amt_ma        0.131804
# medianamnt_ma_rech90    0.120855
# fr_ma_rech90            0.084385
# maxamnt_loans90         0.084144
# rental90                0.075521
# rental30                0.058085
# payback90               0.049183
# payback30               0.048336
# medianamnt_loans30      0.044589
# medianmarechprebal90    0.039300
# medianamnt_loans90      0.035747
# day                     0.006825
# cnt_loans90             0.004733
# cnt_da_rech30           0.003827
# last_rech_date_ma       0.003728
# cnt_da_rech90           0.002999
# ...

# %%
collist=d1.columns.values
ncol=35
nrows=7

# %%
plt.figure(figsize=(ncol,2*ncol))
for i in range (0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(d1[collist[i]],color='green',orient='v')

# %% [markdown]
# From this visualization method,we can see that there are alot of of outliers in this dataset.

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %%
sns.countplot(d1["label"])

# %% [markdown]
# There are nearly about 180000 non defaulters and 25000 defaulters

# %%
sns.countplot(d1["cnt_loans30"])

# %% [markdown]
# No.of loans taken by customers in last 30 days.We can see that customers with no loan history is present.Max no.of customers belongs to 1 loan in a month category.Also we can see that no customers have taken more than 9 or 10 loans in a month.

# %%
plt.subplots(figsize=(10,5))
sns.countplot(d1["amnt_loans30"])

# %% [markdown]
# Total amount of loans taken is maximum for 6.Then for 12.As amount increases,count of customers decreases.

# %%
sns.countplot(d1["maxamnt_loans90"])

# %% [markdown]
# Maximum amount of loans taken by customers is for Rs.6 in 90 days.customer count ranges above 175000. Then around 25000 customers have taken Rs.12 loan and only few have taken no loans at all in these 90 days

# %%
d1['payback90'].hist()
plt.xlabel('avrg payback time in 90 days')
plt.ylabel('count')
plt.show()

# %% [markdown]
# Maximum customers have paid back the loan within 0 to 15 days. And very less people took 15 to 30 days and few have taken 30 to 60 days

# %% [markdown]
# # BIVARIATE ANALYSIS

# %%
sns.barplot(x=d1['label'],y=d1['aon'])

# %% [markdown]
# Defaulters are relatively high for old customers when compared to nondefaulters

# %%
pd.crosstab(d1.label,d1.maxamnt_loans90).plot(kind='bar',figsize=(8,5),color=['#1CA53B','#AA1111'])
plt.title('Frequency of label who take maximum amount of loan')
plt.xlabel('label(0=dafaulter,1=successor)')
plt.xticks(rotation=0)
plt.legend(['have not paid','have paid'])
plt.ylabel('maxamnt_loans90')
plt.show()

# %%
d1.hist(figsize=(20,15))
plt.show()

# %%
#Box plot is the best method to check the presence of outliers
d1["aon"].plot.box()

# %%
d1["daily_decr30"].plot.box()

# %%
d1["rental30"].plot.box()

# %%
d1["last_rech_date_ma"].plot.box()

# %%
d1["cnt_ma_rech30"].plot.box()

# %%
d1["medianamnt_ma_rech90"].plot.box()

# %%
d1["cnt_da_rech30"].plot.box()

# %%
d1["fr_da_rech90"].plot.box()

# %%
d1["amnt_loans30"].plot.box()

# %%
d1["medianamnt_loans30"].plot.box()

# %%
d1["amnt_loans90"].plot.box()

# %%
f, ax=plt.subplots(figsize=(6,4))
sns.lineplot(x='cnt_loans30', y='payback30', hue='label',data=d1)

# %% [markdown]
# This line plot says that defaulters are more than non defaulters in taking loans and also they have taken more days to repay the amount

# %%
f, ax=plt.subplots(figsize=(6,4))
sns.lineplot(x='cnt_loans90', y='payback90', hue='label',data=d1)

# %% [markdown]
# There are 3000 to 3500 default customers who have taken loans in 90 days and some have taken a maximum of around 140 days to repay the amount.

# %%
df=d1.drop("label",axis=1)

# %%
df.shape
# Out:
# (209593, 34)

# %%
df.skew()
# Out:
# aon                     10.392949
# daily_decr30             3.946230
# daily_decr90             4.252565
# rental30                 4.521929
# rental90                 4.437681
# last_rech_date_ma       14.790974
# last_rech_date_da       14.814857
# last_rech_amt_ma         3.781149
# cnt_ma_rech30            3.283842
# fr_ma_rech30            14.772833
# sumamnt_ma_rech30        6.386787
# medianamnt_ma_rech30     3.512324
# medianmarechprebal30    14.779875
# cnt_ma_rech90            3.425254
# fr_ma_rech90             2.285423
# sumamnt_ma_rech90        4.897950
# medianamnt_ma_rech90     3.752706
# medianmarechprebal90    44.880503
# cnt_da_rech30           17.818364
# fr_da_rech30            14.776430
# cnt_da_rech90           27.267278
# fr_da_rech90            28.988083
# cnt_loans30              2.713421
# amnt_loans30             2.975719
# maxamnt_loans30         17.658052
# medianamnt_loans30       4.551043
# cnt_loans90             16.594408
# ...

# %% [raw]
# OBSERVATION
# columns with skewness values above and below 0.55 are skewed datas
# From these skew values we can see that many columns are highly skewed.

# %%
plt.figure(figsize=(20,30))
for i in range(5,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.distplot(df[collist[i]])

# %% [markdown]
# This is the visualization of skewness.We can see that almost all datas are skewed towards right

# %%
#skewness can be removed using yeo_johnson method
from sklearn.preprocessing import power_transform
df=pd.DataFrame(power_transform(df,method='yeo-johnson'),columns=df.columns)
df.skew()
# Out:
# aon                       1.654517
# daily_decr30             -6.582718
# daily_decr90             -7.080191
# rental30                 -1.022844
# rental90                 -0.962717
# last_rech_date_ma        -5.362530
# last_rech_date_da      -106.606657
# last_rech_amt_ma         -0.061262
# cnt_ma_rech30            -0.000145
# fr_ma_rech30              0.165015
# sumamnt_ma_rech30        -0.291322
# medianamnt_ma_rech30     -0.189628
# medianmarechprebal30     -0.119058
# cnt_ma_rech90            -0.002465
# fr_ma_rech90              0.142952
# sumamnt_ma_rech90        -0.192158
# medianamnt_ma_rech90     -0.044604
# medianmarechprebal90      7.506286
# cnt_da_rech30             6.925820
# fr_da_rech30             11.390665
# cnt_da_rech90             6.006577
# fr_da_rech90             15.469700
# cnt_loans30               0.036243
# amnt_loans30              0.001948
# maxamnt_loans30          -1.680107
# medianamnt_loans30        3.447735
# cnt_loans90               0.105580
# ...

# %%
plt.figure(figsize=(20,30))
for i in range(5,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.distplot(df[collist[i]])

# %%
from scipy.stats import zscore
columns=['aon', 'daily_decr30', 'daily_decr90', 'rental30',
       'rental90', 'last_rech_date_ma', 'last_rech_date_da',
       'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
       'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
       'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
       'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
       'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
       'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
       'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
       'payback90']
for i in range(len(columns)):
    df[columns[i]]=zscore(df[columns[i]])
    for j in range(len(df[columns[i]])):
        if df[columns[i]][j]>3 or df[columns[i]][j]<-3:
            df[columns[i]].replace(df[columns[i]][j],df[columns[i]].median(),inplace=True)
            df[columns[i]]=np.cbrt((df[columns[i]]))

# %%
x=df[columns]
y=d1[["label"]]

# %%
print(x.shape)
print(y.shape)
# Out:
# (209593, 32)
# (209593, 1)

# %%
defaulter=d1[d1["label"]==0]
non_defaulter=d1[d1["label"]==1]
print(defaulter.shape,non_defaulter.shape)
# Out:
# (26162, 35) (183431, 35)

# %% [markdown]
# # Random oversampler

# %%
from imblearn.over_sampling import RandomOverSampler
os=RandomOverSampler(random_state=42,sampling_strategy="auto")
x_train_res,y_train_res=os.fit_sample(x,y)

# %% [markdown]
# since the dataset is imbalanced,we have to balance it.we can do either oversampling or under sampling to balance the data.Here I chose random oversampling.It will oversample the minority class by picking samples at random with replacement

# %%
x_train_res.shape,y_train_res.shape
# Out:
# ((366862, 32), (366862, 1))

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x_train_res)
print(x_train_res.shape)
print(y_train_res.shape)
# Out:
# (366862, 32)
# (366862, 1)

# %%
x_train_res.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366862 entries, 0 to 366861
# Data columns (total 32 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   aon                   366862 non-null  float64
#  1   daily_decr30          366862 non-null  float64
#  2   daily_decr90          366862 non-null  float64
#  3   rental30              366862 non-null  float64
#  4   rental90              366862 non-null  float64
#  5   last_rech_date_ma     366862 non-null  float64
#  6   last_rech_date_da     366862 non-null  float64
#  7   last_rech_amt_ma      366862 non-null  float64
#  8   cnt_ma_rech30         366862 non-null  float64
#  9   fr_ma_rech30          366862 non-null  float64
#  10  sumamnt_ma_rech30     366862 non-null  float64
#  11  medianamnt_ma_rech30  366862 non-null  float64
#  12  medianmarechprebal30  366862 non-null  float64
#  13  cnt_ma_rech90         366862 non-null  float64
# ...

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA
c=20
pca=PCA(n_components=c)
x=pca.fit_transform(x_train_res)
x.shape
# Out:
# (366862, 20)

# %% [markdown]
# pca is done to remove multicollinearity.Multicollinearity means the feature columns of a dataset shows high correlation with each other.This may affect our model prediction accuracy and also the result.So PCA is done to resolve this problem

# %%
Y=y_train_res

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,f1_score,roc_curve,roc_auc_score,auc

# %%
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
dtc=  DecisionTreeClassifier()

max_score=0
for r_state in range(40,100):
    x_train,x_test,Y_train,Y_test=train_test_split(x,Y,random_state=r_state,test_size=0.22)
   
    dtc.fit(x_train,Y_train)
    Y_pred=dtc.predict(x_test)
    acc_scr=accuracy_score(Y_test,Y_pred)
    if acc_scr>max_score:
        max_score=acc_scr
        final_r_state=r_state
print("max accuracy score corresponding to",final_r_state,"is",max_score)
# Out:
# max accuracy score corresponding to 44 is 0.9509354478998885

# %%
x_train,x_test,Y_train,Y_test=train_test_split(x,Y,test_size=.22,random_state=44)

# %%
print(x_train.shape)
print(x_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (286152, 20)
# (80710, 20)
# (286152, 1)
# (80710, 1)

# %% [markdown]
# # MODEL PREDICTION

# %%
lr=LogisticRegression()
lr.fit(x_train,Y_train)
lr.score(x_train,Y_train)
predlr=lr.predict(x_test)
print("Accuracy score :",accuracy_score(Y_test,predlr))
print(confusion_matrix(Y_test,predlr))
print(classification_report(Y_test,predlr))
# Out:
# Accuracy score : 0.7676743897906083
# [[32136  8224]
#  [10527 29823]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.80      0.77     40360
#            1       0.78      0.74      0.76     40350
#
#     accuracy                           0.77     80710
#    macro avg       0.77      0.77      0.77     80710
# weighted avg       0.77      0.77      0.77     80710

# %%
gnb=GaussianNB()
gnb.fit(x_train,Y_train)
predgnb=gnb.predict(x_test)
print("Accuracy score :",accuracy_score(Y_test,predgnb))
print(confusion_matrix(Y_test,predgnb))
print(classification_report(Y_test,predgnb))
# Out:
# Accuracy score : 0.7407260562507744
# [[29089 11271]
#  [ 9655 30695]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.72      0.74     40360
#            1       0.73      0.76      0.75     40350
#
#     accuracy                           0.74     80710
#    macro avg       0.74      0.74      0.74     80710
# weighted avg       0.74      0.74      0.74     80710

# %%
dtc=DecisionTreeClassifier()
dtc.fit(x_train,Y_train)
dtc.score(x_train,Y_train)
preddtc=dtc.predict(x_test)
print("Accuracy score :",accuracy_score(Y_test,preddtc))
print(confusion_matrix(Y_test,preddtc))
print(classification_report(Y_test,preddtc))
# Out:
# Accuracy score : 0.950154875480114
# [[40312    48]
#  [ 3975 36375]]
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     40360
#            1       1.00      0.90      0.95     40350
#
#     accuracy                           0.95     80710
#    macro avg       0.95      0.95      0.95     80710
# weighted avg       0.95      0.95      0.95     80710

# %%
knn=KNeighborsClassifier()
knn.fit(x_train,Y_train)
knn.score(x_train,Y_train)
predknn=knn.predict(x_test)
print("Accuracy score :",accuracy_score(Y_test,predknn))
print(confusion_matrix(Y_test,predknn))
print(classification_report(Y_test,predknn))
# Out:
# Accuracy score : 0.8840044604138273
# [[39420   940]
#  [ 8422 31928]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.98      0.89     40360
#            1       0.97      0.79      0.87     40350
#
#     accuracy                           0.88     80710
#    macro avg       0.90      0.88      0.88     80710
# weighted avg       0.90      0.88      0.88     80710

# %%
#AUC-ROC CURVE
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score

# %%
Y_pred_prob=lr.predict_proba(x_test)[:,1]
Y_pred_prob
# Out:
# array([0.86350575, 0.15489882, 0.21663424, ..., 0.16736661, 0.87144385,
#        0.21766666])

# %%
fpr,tpr,thresholds=roc_curve(Y_test,Y_pred_prob)
fpr
# Out:
# array([0.        , 0.        , 0.        , ..., 0.99987611, 0.99995045,
#        1.        ])

# %%
tpr
# Out:
# array([0.00000000e+00, 2.47831475e-05, 2.47831475e-03, ...,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00])

# %%
thresholds
# Out:
# array([1.98848481, 0.98848481, 0.97243326, ..., 0.02053723, 0.02053708,
#        0.01795227])

# %%
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='Logistic Regression')
plt.xlabel('false positive rate')
plt.ylabel('true positive rate')
plt.title('Logistic Regression')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
auc_score=roc_auc_score(Y_test,lr.predict(x_test))
print(auc_score)
# Out:
# 0.7676708508184702

# %%
#Decision tree curve
y_pred_prob=dtc.predict_proba(x_test)[:,0]
fpr,tpr,thresholds=roc_curve(Y_test,Y_pred_prob)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='Decision Tree Classifier')
plt.xlabel('false positive rate')
plt.ylabel('true positive rate')
plt.title('Decision Tree Classifier')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
auc_score=roc_auc_score(Y_test,lr.predict(x_test))
print(auc_score)
# Out:
# 0.7676708508184702

# %% [markdown]
# Decision tree classifier is giving the best result ,so checking its cross_val_score

# %%
from sklearn.model_selection import cross_val_score
dtc=DecisionTreeClassifier()
score=cross_val_score(dtc,x,Y,cv=5)
print("score:",score)
print("Mean score:",score.mean())
print("Standard deviation:",score.std())
# Out:
# score: [0.95119458 0.95116732 0.95030802 0.95111214 0.95111214]
# Mean score: 0.9509788410786015
# Standard deviation: 0.0003369298530099063

# %%
#using ensemble technique to boost our score
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=20,random_state=44)
rf.fit(x_train,Y_train)
print('score:',rf.score(x_train,Y_train))
predrf=rf.predict(x_test)
print('\n')
print("Accuracy score :",accuracy_score(Y_test,predrf))
print(confusion_matrix(Y_test,predrf))
print(classification_report(Y_test,predrf))
# Out:
# score: 0.9991682742039196
#
#
# Accuracy score : 0.9692603147069756
# [[40301    59]
#  [ 2422 37928]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97     40360
#            1       1.00      0.94      0.97     40350
#
#     accuracy                           0.97     80710
#    macro avg       0.97      0.97      0.97     80710
# weighted avg       0.97      0.97      0.97     80710

# %%
rf=RandomForestClassifier()
score=cross_val_score(rf,x,Y,cv=5)
print("score:",score)
print("Mean score:",score.mean())
print("Standard deviation:",score.std())
# Out:
# score: [0.97422758 0.97485451 0.97474513 0.97451344 0.97477239]
# Mean score: 0.974622610581455
# Standard deviation: 0.00022768159168004933

# %%
#saving randomforest classifier

# %%
import joblib
joblib.dump(rf,'rf_micro-credit.pkl')
# Out:
# ['rf_micro-credit.pkl']
